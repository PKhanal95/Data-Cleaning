# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaning.csv')

# %%
df
# Out:
#             location   date_of_sale number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                  1  £729,000
# 1            Ashford     05/08/2017            unknown  £699,000
# 2  Stratford-on-Avon     29/03/2012                  3       NaN
# 3         Canterbury     01/07/2009                  2  £529,000
# 4             Camden     16/12/2001                  1  £616,000
# 5              Rugby     01/03/2003                  -  £247,000
# 6          Hampstead     05/03/2016                  2        £0
# 7            Clapham     05/07/2001                363  £543,000
# 8  Stratford-on-Avon  10th May 2010                  3  £420,000
# 9             Camden     16/12/2001                  1  £616,000
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3        teraced
# 4      apartment
# 5       detached
# 6       terraced
# 7      apartment
# 8       detached
# 9      apartment

# %%
non_nums = df[~df['number_of_bedrooms'].str.isnumeric()]['number_of_bedrooms'].unique()

# %%
df['number_of_bedrooms'] = df['number_of_bedrooms'].replace(non_nums,np.nan)

# %%
df['number_of_bedrooms']
# Out:
# 0      1
# 1    NaN
# 2      3
# 3      2
# 4      1
# 5    NaN
# 6      2
# 7    363
# 8      3
# 9      1
# Name: number_of_bedrooms, dtype: object

# %%
df['number_of_bedrooms'] = pd.to_numeric(df['number_of_bedrooms'])

# %%
df.dtypes
# Out:
# location               object
# date_of_sale           object
# number_of_bedrooms    float64
# price                  object
# type                   object
# dtype: object

# %%
df['price'] = df['price'].apply(lambda x: x.replace('£', '') if type(x) is str else x)

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms    price  \
# 0            Clapham     12/04/1999                 1.0  729,000
# 1            Ashford     05/08/2017                 NaN  699,000
# 2  Stratford-on-Avon     29/03/2012                 3.0      NaN
# 3         Canterbury     01/07/2009                 2.0  529,000
# 4             Camden     16/12/2001                 1.0  616,000
# 5              Rugby     01/03/2003                 NaN  247,000
# 6          Hampstead     05/03/2016                 2.0        0
# 7            Clapham     05/07/2001               363.0  543,000
# 8  Stratford-on-Avon  10th May 2010                 3.0  420,000
# 9             Camden     16/12/2001                 1.0  616,000
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3        teraced
# 4      apartment
# 5       detached
# 6       terraced
# 7      apartment
# 8       detached
# 9      apartment

# %%
df['price'] = df['price'].apply(lambda x: x.replace(',', '') if type(x) is str else x)

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms   price           type
# 0            Clapham     12/04/1999                 1.0  729000      apartment
# 1            Ashford     05/08/2017                 NaN  699000  semi-detached
# 2  Stratford-on-Avon     29/03/2012                 3.0     NaN       detached
# 3         Canterbury     01/07/2009                 2.0  529000        teraced
# 4             Camden     16/12/2001                 1.0  616000      apartment
# 5              Rugby     01/03/2003                 NaN  247000       detached
# 6          Hampstead     05/03/2016                 2.0       0       terraced
# 7            Clapham     05/07/2001               363.0  543000      apartment
# 8  Stratford-on-Avon  10th May 2010                 3.0  420000       detached
# 9             Camden     16/12/2001                 1.0  616000      apartment

# %%
df['price'] = pd.to_numeric(df['price'])

# %%
df.dtypes
# Out:
# location               object
# date_of_sale           object
# number_of_bedrooms    float64
# price                 float64
# type                   object
# dtype: object

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                 1.0  729000.0
# 1            Ashford     05/08/2017                 NaN  699000.0
# 2  Stratford-on-Avon     29/03/2012                 3.0       NaN
# 3         Canterbury     01/07/2009                 2.0  529000.0
# 4             Camden     16/12/2001                 1.0  616000.0
# 5              Rugby     01/03/2003                 NaN  247000.0
# 6          Hampstead     05/03/2016                 2.0       NaN
# 7            Clapham     05/07/2001               363.0  543000.0
# 8  Stratford-on-Avon  10th May 2010                 3.0  420000.0
# 9             Camden     16/12/2001                 1.0  616000.0
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3       terraced
# 4      apartment
# 5       detached
# 6       terraced
# 7      apartment
# 8       detached
# 9      apartment

# %%
df['price'] = df['price'].replace([0], np.nan)

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                 1.0  729000.0
# 1            Ashford     05/08/2017                 NaN  699000.0
# 2  Stratford-on-Avon     29/03/2012                 3.0       NaN
# 3         Canterbury     01/07/2009                 2.0  529000.0
# 4             Camden     16/12/2001                 1.0  616000.0
# 5              Rugby     01/03/2003                 NaN  247000.0
# 6          Hampstead     05/03/2016                 2.0       NaN
# 7            Clapham     05/07/2001               363.0  543000.0
# 8  Stratford-on-Avon  10th May 2010                 3.0  420000.0
# 9             Camden     16/12/2001                 1.0  616000.0
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3       terraced
# 4      apartment
# 5       detached
# 6       terraced
# 7      apartment
# 8       detached
# 9      apartment

# %%
df['type'].unique()
# Out:
# array(['apartment', 'semi-detached', 'detached', 'terraced'], dtype=object)

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                 1.0  729000.0
# 1            Ashford     05/08/2017                 NaN  699000.0
# 2  Stratford-on-Avon     29/03/2012                 3.0       NaN
# 3         Canterbury     01/07/2009                 2.0  529000.0
# 4             Camden     16/12/2001                 1.0  616000.0
# 5              Rugby     01/03/2003                 NaN  247000.0
# 6          Hampstead     05/03/2016                 2.0       NaN
# 7            Clapham     05/07/2001               363.0  543000.0
# 8  Stratford-on-Avon  10th May 2010                 3.0  420000.0
# 9             Camden     16/12/2001                 1.0  616000.0
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3       terraced
# 4      apartment
# 5       detached
# 6       terraced
# 7      apartment
# 8       detached
# 9      apartment

# %%
df.plot.box(x='price')

# %%
df.plot.box(x='number_of_bedrooms')

# %%
df.loc[7, 'number_of_bedrooms'] = np.nan

# %%
df = df.drop(7)

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                 1.0  729000.0
# 1            Ashford     05/08/2017                 NaN  699000.0
# 2  Stratford-on-Avon     29/03/2012                 3.0       NaN
# 3         Canterbury     01/07/2009                 2.0  529000.0
# 4             Camden     16/12/2001                 1.0  616000.0
# 5              Rugby     01/03/2003                 NaN  247000.0
# 6          Hampstead     05/03/2016                 2.0       NaN
# 8  Stratford-on-Avon  10th May 2010                 3.0  420000.0
# 9             Camden     16/12/2001                 1.0  616000.0
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3       terraced
# 4      apartment
# 5       detached
# 6       terraced
# 8       detached
# 9      apartment

# %%
df.duplicated(subset=None, keep='first')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 8    False
# 9     True
# dtype: bool

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#             location   date_of_sale  number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                 1.0  729000.0
# 1            Ashford     05/08/2017                 NaN  699000.0
# 2  Stratford-on-Avon     29/03/2012                 3.0       NaN
# 3         Canterbury     01/07/2009                 2.0  529000.0
# 4             Camden     16/12/2001                 1.0  616000.0
# 5              Rugby     01/03/2003                 NaN  247000.0
# 6          Hampstead     05/03/2016                 2.0       NaN
# 8  Stratford-on-Avon  10th May 2010                 3.0  420000.0
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3       terraced
# 4      apartment
# 5       detached
# 6       terraced
# 8       detached

# %%
df.isnull().mean()
# Out:
# location              0.00
# date_of_sale          0.00
# number_of_bedrooms    0.25
# price                 0.25
# type                  0.00
# dtype: float64

# %%
mean = df['price'].mean()
df['price'].fillna(value=mean)
# Out:
# 0    729000.0
# 1    699000.0
# 2    540000.0
# 3    529000.0
# 4    616000.0
# 5    247000.0
# 6    540000.0
# 8    420000.0
# Name: price, dtype: float64
